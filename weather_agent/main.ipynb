# %%
from openai import OpenAI
from google import genai
from dotenv import load_dotenv
import os
import requests

# %%
load_dotenv()
# Out:
# True

# %%
client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

# %%
def get_weather(city: str):
    url = f"https://wttr.in/{city.lower()}?format=%C+%t"
    response = requests.get(url)

    if response.status_code == 200:
        return f"The weather in {city} is {response.text}"
    
    return "Something went wrong"

# %%
def main():
    user_query = input("> ")
    response = client.models.generate_content(
        model="gemini-2.5-flash-lite",
        contents=[
            {"role": "user", "parts": [{"text": user_query}]}
        ]
    )

    print(f"Bot: {response.text}")

main()
# Out:
# Bot: I cannot provide real-time weather information. My knowledge is based on the data I was trained on, which is not current.
#
# To get the current temperature in Celsius in Goa, you can use a reliable weather source such as:
#
# *   A weather app on your smartphone
# *   A weather website (e.g., AccuWeather, Weather.com, BBC Weather)
# *   A quick search on Google for "weather Goa"

# %%
print(get_weather("jaipur"))
# Out:
# The weather in jaipur is Haze +23°C
