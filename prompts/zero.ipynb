# %% [markdown]
# ## Zero Shot Prompting

# %%
from dotenv import load_dotenv
from openai import OpenAI
from groq import Groq
import os
from google import genai

# %%
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/"
)

# %%
# Zero Shot Prompting: Directly giving the inst to the model
SYSTEM_PROMPT = "you should only and only ans the coding related questions. Do not ans anything else. your name is Alexa. If user asks something other than coding, just say sorry "

# %%
response = client.chat.completions.create(
    model="gemini-2.5-flash-lite",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": "Hey, Can you write a python code to translate english to hindi"}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Sure, I can help you with that. Here's a Python code using the `googletrans` library to translate English to Hindi:
#
# First, you need to install the library if you haven't already:
#
# ```bash
# pip install googletrans==4.0.0-rc1
# ```
#
# Now, here's the Python code:
#
# ```python
# from googletrans import Translator
#
# def translate_english_to_hindi(text):
#   """
#   Translates English text to Hindi.
#
#   Args:
#     text: The English text to translate.
#
#   Returns:
#     The translated Hindi text, or an error message if translation fails.
#   """
#   try:
#     translator = Translator()
#     translation = translator.translate(text, src='en', dest='hi')
#     return translation.text
#   except Exception as e:
#     return f"An error occurred during translation: {e}"
#
# if __name__ == "__main__":
#   english_text = input("Enter the English text you want to translate: ")
#   hindi_translation = translate_english_to_hindi(english_text)
#   print(f"Hindi translation: {hindi_translation}")
# ```
#
# **How this code works:**
#
# 1.  **`from googletrans import Translator`**: This line imports the `Translator` class from the `googletrans` library.
# 2.  **`def translate_english_to_hindi(text):`**: This defines a function that takes the English text as an argument.
# 3.  **`translator = Translator()`**: This creates an instance of the `Translator` class.
# 4.  **`translation = translator.translate(text, src='en', dest='hi')`**: This is the core of the translation.
#     *   `text`: The input English text.
#     *   `src='en'`: Specifies the source language as English.
#     *   `dest='hi'`: Specifies the destination language as Hindi.
# 5.  **`return translation.text`**: The `translate` method returns a `Translation` object, and `.text` accesses the translated string.
# 6.  **`except Exception as e:`**: This block handles any potential errors that might occur during the translation process (e.g., network issues).
# 7.  **`if __name__ == "__main__":`**: This block ensures that the code inside it only runs when the script is executed directly (not when imported as a module).
#     *   It prompts the user to enter English text.
#     *   It calls the `translate_english_to_hindi` function.
#     *   It prints the resulting Hindi translation.
#
# **Example Usage:**
#
# If you run this code and enter:
#
# `Hello, how are you?`
#
# The output will be:
#
# `Hindi translation: नमस्ते आप कैसे हैं?`
